# %% [markdown]
# # Task 1: Data Dashboard And Storytelling
#
# Alex Rivera ID#011243153
#
# Western Governors University
#
# D210 - Representation and Reporting
#
# October 23, 2023
#
# ## A: Interactive Data Dashboard
#
# A copy of the interactive Tableau dashboard can be found in the Tableau Public link below:
#
# https://public.tableau.com/views/D210RepresentationandReporting_16977895227320/Story1?:language=en-US&:display_count=n&:origin=viz_share_link
#
# The dashboard is accessible to users with colorblindness and adheres to the requirements of the rubric provided.
#
# ## A1: Data Sets
#
# There were two source data sets utilized for the Tableau project. First, the churn_clean CSV dataset that was provided with the coursework. Second, an American Community Survey on Types of Internet Subscriptions by Selected Characteristics found on the United States Census Bureau data platform(U.S. Census Bureau, 2022). The churn_clean and ACSST1Y2022.S2802 CSVs were submitted along with the project. Below is a Python script implemented to manipulate and combine the datasets for usage within Tableau.

# %%
import pandas as pd 
import numpy as np

# %%
churn = pd.read_csv('C:/Users/alexa/WGU/D210/Project/churn_clean.csv', index_col=0)

pd.set_option("display.max_columns", None)

# %%
report_churn = churn[["State","Age","Churn","InternetService"]].copy()

# %%
report_churn.loc[report_churn['Age'] <65 ,'Age_Group'] = '18 to 64 years'
report_churn.loc[report_churn['Age'] >=65 ,'Age_Group'] = '65 years and over'
report_churn['Internet'] = np.where(report_churn['InternetService'] == 'None', 'No', 'Yes')
report_churn = report_churn.replace('Yes', 1)
report_churn = report_churn.replace('No', 0)
report_churn['National'] = 'National'
report_churn
# Out:
#           State  Age  Churn InternetService          Age_Group  Internet  \
# CaseOrder
# 1            AK   68      0     Fiber Optic  65 years and over         1
# 2            MI   27      1     Fiber Optic     18 to 64 years         1
# 3            OR   50      0             DSL     18 to 64 years         1
# 4            CA   48      0             DSL     18 to 64 years         1
# 5            TX   83      1     Fiber Optic  65 years and over         1
# ...         ...  ...    ...             ...                ...       ...
# 9996         VT   23      0             DSL     18 to 64 years         1
# 9997         TN   48      0     Fiber Optic     18 to 64 years         1
# 9998         TX   48      0     Fiber Optic     18 to 64 years         1
# 9999         GA   39      0     Fiber Optic     18 to 64 years         1
# 10000        GA   28      0     Fiber Optic     18 to 64 years         1
#
#            National
# CaseOrder
# 1          National
# 2          National
# ...

# %%
national = pd.read_csv('C:/Users/alexa/WGU/D210/Project/ACSST1Y2022.S2802-2023-10-09T071926.csv', index_col=0)

# %%
national = national[["United States!!With a computer!!Percent  Broadband Internet Subscription!!Estimate"]].copy()

# %%
national = national.iloc[0:5].copy()

# %%
national = national.dropna()
national.rename(columns={"United States!!With a computer!!Percent  Broadband Internet Subscription!!Estimate":"National_P"}, inplace=True)

# %%
national.index.names = ['Groups']
national.reset_index(inplace=True)
national['National'] = 'National'

# %%
national = national.pivot(index='National', columns = 'Groups', values='National_P')
national
# Out:
# Groups   18 to 64 years 65 years and over Total population in households  \
# National
# National         94.30%            84.80%                         92.90%
#
# Groups   Under 18 years
# National
# National         95.40%

# %%
national = national[["18 to 64 years","65 years and over","Total population in households"]].copy()
national.reset_index(inplace=True)

# %%
national = national.merge(report_churn, how='inner', left_on='National', right_on='National')
national
# Out:
#       National 18 to 64 years 65 years and over  \
# 0     National         94.30%            84.80%
# 1     National         94.30%            84.80%
# 2     National         94.30%            84.80%
# 3     National         94.30%            84.80%
# 4     National         94.30%            84.80%
# ...        ...            ...               ...
# 9995  National         94.30%            84.80%
# 9996  National         94.30%            84.80%
# 9997  National         94.30%            84.80%
# 9998  National         94.30%            84.80%
# 9999  National         94.30%            84.80%
#
#      Total population in households State  Age  Churn InternetService  \
# 0                            92.90%    AK   68      0     Fiber Optic
# 1                            92.90%    MI   27      1     Fiber Optic
# 2                            92.90%    OR   50      0             DSL
# 3                            92.90%    CA   48      0             DSL
# ...

# %%
national.loc[national['Age_Group'] == '18 to 64 years' ,'Age_GroupP'] = national['18 to 64 years']
national.loc[national['Age_Group'] == '65 years and over' ,'Age_GroupP'] = national['65 years and over']
national
# Out:
#       National 18 to 64 years 65 years and over  \
# 0     National         94.30%            84.80%
# 1     National         94.30%            84.80%
# 2     National         94.30%            84.80%
# 3     National         94.30%            84.80%
# 4     National         94.30%            84.80%
# ...        ...            ...               ...
# 9995  National         94.30%            84.80%
# 9996  National         94.30%            84.80%
# 9997  National         94.30%            84.80%
# 9998  National         94.30%            84.80%
# 9999  National         94.30%            84.80%
#
#      Total population in households State  Age  Churn InternetService  \
# 0                            92.90%    AK   68      0     Fiber Optic
# 1                            92.90%    MI   27      1     Fiber Optic
# 2                            92.90%    OR   50      0             DSL
# 3                            92.90%    CA   48      0             DSL
# ...

# %%
national.to_csv('C:/Users/alexa/WGU/D210/Project/National_Prepared_Data.csv', index=False)

# %% [markdown]
# ## A2: Installation Instructions
#
# Installation is not applicable as the interactive Tableau project is freely hosted on Tableau Public. To start utilizing the interactive dashboard, please open the link in any preferred browser:
#
# https://public.tableau.com/app/profile/alex.rivera1136/viz/D210RepresentationandReporting_16977895227320/Story1
#
# ## A3: Navigation Instructions
#
# The interactive dashboard project is composed of a story with two story points, which is a minimalist way of displaying two dashboards created. The two story points are based on two different groups of metrics. First, national/state customer internet averages. Second, customer internet averages are based on age groups. Selecting National/State AVG on the top center loads the first dashboard which includes two filters on the top right for Customer Churn and State selections. The National/State AVG dashboard has four data representations:
#
# - Customer Nation Internet AVG on the top which highlights the current customer percentage with an internet subscription versus the national internet average and the variance to that national average.
# - Customer State Internet AVG shows the customer percentage of the current selection of the state filter with an internet subscription versus the national internet average and the variance to that national average.
# - States Ranked by Internet AVG on the bottom left ranks all states in descending order by customer internet subscription versus the national reference line.
# - Customer Counts by State on the bottom right is a map with a visual size representation of customers within each state.
#
# The story point selection on the top center of Age Group AVG displays the relevant dashboard for Age groups with two filters for Age Group and State. The age group filter is a single selection dropdown that interacts with the state data presentations. This dashboard is composed of three data presentations:
#
# - Customer Nation Internet Age AVG on the top highlights the current customer percentage with an internet subscription versus the national internet average and the variance to that national average.
#     - The data presentation and metrics are broken down into the two age groups of 18 to 64 years and 65 years & older.
# - Customer State Internet Age AVG in the middle is the current selection of the state filter with an internet subscription versus the national internet age group average and the variance to that national age group average.
# - States Ranked by Internet Age AVG bottom ranks all states in descending order by customer internet subscription versus the national age group reference line.
#
# ## B: Panopto Storytelling With Data
#
# https://wgu.hosted.panopto.com/Panopto/Pages/Viewer.aspx?id=b2be1429-8520-47a7-a0af-b0a401564b22
#
# ## C1: Dashboard Alignment
#
# In the data dictionary, three takeaways guided me in the path of building the interactive dashboard in the project (D210 Churn Data Consideration and Dictionary, 2023):
#
#     - Given that it costs 10 times more to acquire a new customer than to retain an existing one, customer retention has now become even more important than customer acquisition.
#     - Build a data dashboard to enable executive leaders to explore the data, identify trends, and compare key metrics.
#     - Present broad and understandable insights from the data that are relevant to their perspective.
#
# I focused on the internet subscription average as my focus for the dashboard as these are current customers that we can retain at a lower cost and offer additional services. The chosen supplemental dataset provides national internet subscription data as a whole and by age group for the creation of metrics, section C2 will discuss the insights of this dataset. I built interactive dashboards with the executive team's focuses in mind when incorporating the data representations, audience analysis will be discussed further in section C7. The interactive controls help focus on areas that their perspective teams might need to dive deep to analyse. I also chose to use two dashboards to focus on internet subscription average by age group to align with leaders that focused on behavior and demographics.
#
# ## C2: Additional Data Set Insights
#
# The data dictionary lays out the need for identifying trends and comparing key metrics with no mention of the current performance of the company or past data to identify a trend. The first thing that came to mind is having a baseline to compare against and the American Community Survey on Types of Internet Subscriptions by Selected Characteristics provided national figures as a whole and by age group to compare to. Now being able to summarize the customer churn database and compare it to the second dataset with the figure provides valuable insights to action on. Actionable insights will be presented in the Panopto presentation.
#
# ## C3: Decision-Making Support
#
# The first interactive dashboard was made to have the impact of an executive dashboard. This led me to create simple data representations that highlight important metrics and are sorted to highlight actionable items. Customer National Internet AVG is made up of aggregate customers with an internet subscription and the variance to the national average. This data representation is made to refresh anytime the data is updated to act as a pulse check of how the company's internet subscription is currently doing. Executives can use this average to determine the company's health and if any strategies need to be put in place to impact the metric. States Ranked by Internet AVG is a data representation that breakouts and sorts the Internet average by state in descending order. Executives and Regional VPs can use this data representation to take a deep dive on states that not performing as well as the national internet average. The state rankings can also be compared by selection in the state filter which will be discussed further in section C4.
#
# ## C4: Interactive Controls
#
# The State interactive control is found on both dashboards, it impacts all the data representation minus the two national representations on the top of each page. The state filter was implemented due to the audience overview mentioned in the data dictionary. With the executive team having regional duties it seemed fitting to along the ability to drill down into regions or states to understand internet subscription averages they are responsible for. A comparison of states is also possible with the filter. The Age Group interactive control is found on the Age Group AVG dashboard which is a single selection drop-down to separate the age group metrics. The age group filter along with the state filter along further insights of state or region.
#
#
# ## C5: Colorblindness
#
# I made an attempt to minimize the use of color wherever possible and use grayscale in the dashboards. Sandra Caballer's blog post was a helpful resource for understanding the impact of color on someone with colorblindness. The blog post continued to give advice on how to implement color with minimal impact. One of the tips I implemented was, "If you would like to use two colors, try to use blue and orange. These will always be your ally, as they are considered the best color-friendly palette because of their evident contrast" (Caballer, 2023).
#
# ## C6: Data Representations
#
# The story I wanted to highlight through the data representations are metrics comparing the current and national internet subscription averages. A metric is unbiased and highlights the current conditions compared to a baseline that can also be used to trend over time. The Customer National Internet AVG highlights the story of company performance as a whole for internet subscriptions, this is a quick pulse check that is loaded to see how the company is performing. The States Ranked by Internet AVG are in descending order and highlight states in need of attention to the executives.
#
# ## C7: Audience Analysis
#
# A key takeaway from Goodman's book highlights my top focus from audience analysis that was implemented in my presentation, "An audience-centered speaker gathers information about their audience and uses it to adjust speaking content and strategies" (Goodman et al., 2023). The data dictionary's breakdown of the executive was a guide for creating the data presentations and metrics. I made sure to focus on what the audience could relate to to keep them engaged and have something to act on coming out of my presentation.
#
# ## C8: Universal Access
#
# The first aspect of universal access is making sure to accommodate any individual with the possibility of color blindness. Another huge contribution to universal access is utilizing Tableau Public to host the completed dashboard. Without the need for installation and availability anywhere with an internet connection. Below are two points the Tableau site highlighted (Tableau Public, 2023).
#
# - Published visualizations are available for anyone to see online.
#
# - Fully hosted: Tableau Public vizzes can handle millions of viewers. All infrastructure is managed by us at no cost.
#
# ## C9: Effective Storytelling
#
# There were two effective storytelling rules I followed from a Indeed article, "Follow a clear structure and ensure the audience can relate" (10 rules for great storytelling (with tips to improve) - indeed, 2023). Following a clear structure helped keep the audience engaged throughout the concise presentation. Ensuring the audience can relate was something I implemented from the dashboard to throughout the presentation, knowing the audience can find value in what I am providing ensures engagement.
#
# ## D: Sources
#
# Caballer, S. (2023, May 15). Decision intelligence blog: Reports, Dashboarding and color blindness. Pyramid Analytics User Community. https://community.pyramidanalytics.com/t/g9h48j3/decision-intelligence-blog-reports-dashboarding-and-color-blindness
#
# Goodman, Dr. L., Amber Green, M. A., &amp; Various. (n.d.). Audience analysis. Public Speaking. https://open.maricopa.edu/com225/chapter/need-to-find-audience-analysis-reading/
#
# Tableau Public. Tableau. (n.d.). https://www.tableau.com/products/public
#
# U.S. Census Bureau. (2022). Types of Internet Subscriptions by Selected Characteristics. American Community Survey, ACS 1-Year Estimates Subject Tables, Table S2802. Retrieved October 18, 2023, from https://data.census.gov/table/ACSST1Y2022.S2802?q=Telephone,+Computer,+and+Internet+Access&moe=false.
#
# Western Governors University. (2023). D210 Churn Data Consideration and Dictionary. Millcreek.
